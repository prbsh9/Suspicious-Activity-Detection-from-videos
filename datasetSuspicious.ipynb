# %% [markdown]
# # Importing and syncing with colab

# %%
#some initial things for easiness
# !pip install -i https://test.pypi.org/simple/ supportlib
# !sudo apt-get install -y python-dev pkg-config
# !sudo apt-get install -y \
    libavformat-dev libavcodec-dev libavdevice-dev \
    libavutil-dev libswscale-dev libswresample-dev libavfilter-dev
# !pip install av

import supportlib.gettingdata as getdata

import av
import glob
import os
import time
import tqdm
import datetime
import argparse
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# python-dev is already the newest version (2.7.15~rc1-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libavcodec-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libavdevice-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libavfilter-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libavformat-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libavutil-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# ...

# %%
# import shutil
# shutil.rmtree('PicturesData')

# os.mkdir('Pictures/Robbery')

# %%
from google.colab import drive
drive.mount('/drive')
import os
path = '/drive/My Drive/suspicious_activity/content/'
os.chdir(path)
os.getcwd()
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# '/drive/My Drive/suspicious_activity/content'

# %%
# import shutil
# shutil.move('Training-Normal-Videos-Part-1','Sample_Videos' )
# Out:
# 'Sample_Videos/Training-Normal-Videos-Part-1'

# %%
import cv2
# def video_to_frame(path,out_path):
#   delayTime = 10000
#   cv2.waitKey(0)
#   vidcap = cv2.VideoCapture(path)
#   # vidcap.set(cv2.cv.CV_CAP_PROP_FPS, 60)
#   success,image = vidcap.read()
#   count = 0

#   while success:
#     cv2.waitKey(0)
#     cv2.imwrite(out_path +"{}.jpg".format(count), image)
#     success,image = vidcap.read()
#     count += 1

def extractImages(pathIn, pathOut):
  vidcap = cv2.VideoCapture(pathIn)
  success,image = vidcap.read()
  count = 0
  while success:
    cv2.imwrite(pathOut +"{}.jpg".format(count), image)     # save frame as JPEG file      
    success,image = vidcap.read()
    print('Read a new frame: ', success)
    count += 1
      

for videos in os.listdir('Small_Dataset/Normal'):
	extractImages('Small_Dataset/Normal/' + videos, 'frameLocally/Normal/'+ videos[:-4])
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
# !du -h frameLocally
# Out:
# 1.8G	frameLocally/Normal
# 277M	frameLocally/Assault
# 300M	frameLocally/Robbery
# 623M	frameLocally/Fighting
# 544M	frameLocally/RoadAccidents
# 5.1G	frameLocally

# %%
os.chdir('..')
# os.getcwd()
# len(os.listdir())
# os.getcwd()
# os.chdir('../..')

# %%
def extractImages(pathIn, pathOut):
    count = 1
    vidcap = cv2.VideoCapture(pathIn)
    success,image = vidcap.read()
    success = True
    while success:
        vidcap.set(cv2.CAP_PROP_POS_MSEC,(count*400))    # added this line 
        success,image = vidcap.read()
        print ('Read a new frame: ', success)
        cv2.imwrite( pathOut + " {}.jpg".format(count), image)     # save frame as JPEG file
        count = count + 1
    print('New PHOTO START')


for videos in os.listdir('Small_Dataset/Robbery'):
	extractImages('vids/Robbery/' + videos, 'data/Robbery/'+videos)
# Out:
# Read a new frame:  False
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-58-54024e637826> in <module>()
#      15
#      16 for videos in os.listdir('Small_Dataset/Normal'):
# ---> 17         extractImages('vids/Normal/' + videos, 'data/Normal/'+videos)
#      18
#
# <ipython-input-58-54024e637826> in extractImages(pathIn, pathOut)
#       9         success,image = vidcap.read()
#      10         print ('Read a new frame: ', success)
# ---> 11         cv2.imwrite( pathOut + " {}.jpg".format(count), image)     # save frame as JPEG file
#      12         count = count + 1
#      13     print('New PHOTO START')
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgcodecs/src/loadsave.cpp:715: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %%
os.listdir()
# Out:
# ['UCF101.rar',
#  '.config',
#  '.ipynb_checkpoints',
#  'Normal_Videos_for_Event_Recognition',
#  'Testing_Normal_Videos_Anomaly',
#  'Anomaly-Videos-Training',
#  'others',
#  'Training-Normal-Videos-Part-2.zip?dl=0',
#  'Dataset',
#  'Small_Dataset',
#  'Frames',
#  'uc?export=download&confirm=MdTi&id=1vo2TBWFlA-yish_h8CgxIrSHnqCHxUUM',
#  'uc?id=1vo2TBWFlA-yish_h8CgxIrSHnqCHxUUM',
#  'Pictures',
#  'picturesData',
#  'five-video-classification-methods',
#  '1_move_files.py',
#  'data']

# %%
def extract_frames(video_path):
    frames = []
    video = av.open(video_path)
    for frame in video.decode(0):
        yield frame.to_image()

import os
# Anomaly videos part1
from tqdm.autonotebook import tqdm
path = 'Small_Dataset'
result = 'data'

for i in tqdm(os.listdir(path)):
  p1 = os.path.join(path,i)
  r1 = os.path.join(result,i)
  if os.path.exists(r1):
            continue
  os.makedirs(r1,exist_ok = True)
  for j in os.listdir(p1):
    vid_path = os.path.join(p1,j)
    r2 = os.path.join(r1,j[:-4])
    os.makedirs(r2,exist_ok = True)
    for j, frame in enumerate((extract_frames(vid_path))):
      frame.save(r2+ ' @'+ f"{j}.jpg")
# Out:
# ...
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# stream 0, timescale not set
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8d51c8e273c0> in <module>()
#      23     os.makedirs(r2,exist_ok = True)
#      24     for j, frame in enumerate((extract_frames(vid_path))):
# ---> 25       frame.save(r2+ ' @'+ f"{j}.jpg")
#
# ...

# %%
# os.chdir('Frames/Fighting')
# os.listdir()
import os
for vdo in os.listdir():
  for pic in os.listdir(vdo):
    # print('transferring from'+ os.path.join(vdo,pic) +'to'+os.path.join(os.getcwd(), vdo+'@'+pic)  )
    os.rename(os.path.join(vdo,pic), os.path.join(os.getcwd(), vdo+'@'+pic))

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import shutil
shutil.rmtree('Fighting011_x264')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3.6/shutil.py in rmtree(path, ignore_errors, onerror)
#     479         try:
# --> 480             fd = os.open(path, os.O_RDONLY)
#     481         except Exception:
#
# OSError: [Errno 5] Input/output error: 'Fighting011_x264'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c6be372ea7b2> in <module>()
#       1 import shutil
# ----> 2 shutil.rmtree('Fighting011_x264')
#
# /usr/lib/python3.6/shutil.py in rmtree(path, ignore_errors, onerror)
#     478             return
#     479         try:
# --> 480             fd = os.open(path, os.O_RDONLY)
#     481         except Exception:
#     482             onerror(os.lstat, path, sys.exc_info())
#
# KeyboardInterrupt:

# %%
# def extract_frames(video_path):

  
#   container = av.open(video_path)
#   for frame in container.decode(0):
#       frame.to_image().save('frame-%04d.jpg' % frame.index)
      

def video_to_frame(path,out_path):
  delayTime = 100
  cv2.waitKey(delayTime)
  vidcap = cv2.VideoCapture(path)
  # vidcap.set(cv2.cv.CV_CAP_PROP_FPS, 60)
  success,image = vidcap.read()
  count = 0

  while success:
    cv2.waitKey(delayTime)
    cv2.imwrite(r2 +"{}.jpg".format(count), image)
    success,image = vidcap.read()
    count += 5



# Anomaly videos part1
from tqdm.autonotebook import tqdm
path = 'Small_Dataset'
result = 'justForTest'

for i in tqdm(os.listdir(path)):
  p1 = os.path.join(path,i)
  r1 = os.path.join(result,i)
  if os.path.exists(r1):
    continue
  os.makedirs(r1,exist_ok = True)

  for j in os.listdir(p1):
    vid_path = os.path.join(p1,j)
    r2 = os.path.join(r1,j[:-4])
    os.makedirs(r2,exist_ok = True)

    for j, frame in enumerate((video_to_frame(vid_path, result))):
      print('Fuck you')
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-a0dd89347c60> in <module>()
#      35     os.makedirs(r2,exist_ok = True)
#      36
# ---> 37   for j, frame in enumerate((video_to_frame(vid_path, result))):
#      38     print('Fuck you')
#
# TypeError: 'NoneType' object is not iterable

# %%
# import sys
# import argparse
# import os
# import cv2
# print(cv2.__version__)

# def extractImages(pathIn, pathOut):
#     count = 1
#     vidcap = cv2.VideoCapture(pathIn)
#     success,image = vidcap.read()
#     success = True
#     while success:
#         vidcap.set(cv2.CAP_PROP_POS_MSEC,(count*1000))    # added this line 
#         success,image = vidcap.read()
#         print ('Read a new frame: ', success)
#         cv2.imwrite( pathOut + " {}.jpg".format(count), image)     # save frame as JPEG file
#         count = count + 2
#     print('New PHOTO START')





# for videos in os.listdir('Small_Dataset/Normal'):
# 	extractImages('Small_Dataset/Normal/' + videos, 'Pictures/Normal/' + videos)

# %%
# Are every images of size 320 by  240?

# from PIL import Image
# for folder in os.listdir():
#   for images in os.listdir(folder):
    

#     im = Image.open(folder+'/'+ images)
#     width, height = im.size
#     if width != 320:
#       print(width, height)

# %% [markdown]
# # Training part now

# %%
import math, os
import numpy as np
import keras
from keras.layers import Dropout, Flatten, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Dense
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras.preprocessing import image


PATH = os.getcwd()
# Define data path
DATASET_DIR = PATH + '/Frames'

SIZE = (224, 224)
BATCH_SIZE = 32
VALIDATION_SPLIT = 0.3
IMG_SIZE = ( 224, 224, 3)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# How many data and classes ..
num_dataset_samples = sum([len(files) for r, d, files in os.walk(DATASET_DIR)])

np.random.seed(42)
num_train_steps = math.floor((num_dataset_samples*(1-VALIDATION_SPLIT))/BATCH_SIZE)
num_valid_steps = math.floor((num_dataset_samples*VALIDATION_SPLIT)/BATCH_SIZE)

generator = image.ImageDataGenerator(validation_split=VALIDATION_SPLIT)

batches = generator.flow_from_directory(DATASET_DIR, subset='training', target_size=SIZE, class_mode='categorical', shuffle=True, batch_size=BATCH_SIZE)
val_batches = generator.flow_from_directory(DATASET_DIR, subset='validation', target_size=SIZE, class_mode='categorical', shuffle=True, batch_size=BATCH_SIZE)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3.6/os.py in walk(top, topdown, onerror, followlinks)
#     347         # to earlier import-*.
# --> 348         scandir_it = scandir(top)
#     349     except OSError as error:
#
# OSError: [Errno 5] Input/output error: '/drive/My Drive/suspicious_activity/content/Frames/Normal/Normal_Videos028_x264'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b4a7536adf11> in <module>()
# ----> 1 num_dataset_samples = sum([len(files) for r, d, files in os.walk(DATASET_DIR)])
#       2
#       3 np.random.seed(42)
#       4 num_train_steps = math.floor((num_dataset_samples*(1-VALIDATION_SPLIT))/BATCH_SIZE)
#       5 num_valid_steps = math.floor((num_dataset_samples*VALIDATION_SPLIT)/BATCH_SIZE)
#
# ...
